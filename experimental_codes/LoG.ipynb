# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import cv2
from convolution import conv2
from generate_log import generate_log

# %%
mask = generate_log(2.2)

# %%
plt.imshow(mask)
plt.show()

# %%
image = cv2.imread("TestImages4Project//butterfly.jpg")

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.imshow(gray_image.astype('uint8'), cmap = 'gray')
plt.show()

# %%
edge_gray_image = conv2(gray_image, mask, pad = 0)

# %%
plt.imshow(edge_gray_image, cmap = 'gray')
plt.show()
